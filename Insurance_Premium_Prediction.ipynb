# %%
import os
os.chdir("D:\Insurance")
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("insurance.csv")

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df.sex)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df['sex'].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
df.sex.value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# # Checking the bmi Column

# %%
sns.histplot(df.bmi)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Count'>

# %%
sns.distplot(df.bmi)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
sns.boxplot(df.bmi)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi'>

# %% [markdown]
# Checking the children Column

# %%
sns.countplot(df.children)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='children', ylabel='count'>

# %%
df.children.value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='children'>

# %%
df.children
# Out:
# 0       0
# 1       1
# 2       3
# 3       0
# 4       0
#        ..
# 1333    3
# 1334    0
# 1335    0
# 1336    0
# 1337    0
# Name: children, Length: 1338, dtype: int64

# %% [markdown]
# Checking the smoker Column

# %%
sns.countplot(df.smoker)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
df['smoker'].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='smoker'>

# %%
df.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %% [markdown]
# Checking the region Column

# %%
sns.countplot(df.region)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
df['region'].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='region'>

# %%
df.region
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# # Checking the Two Columns with eachother

# %% [markdown]
# age Vs bmi

# %%
sns.scatterplot(df["age"], df["bmi"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.regplot(df["age"], df["bmi"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %% [markdown]
# age vs expenses

# %%
sns.scatterplot(df.age,df.expenses)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.regplot(df["age"], df["expenses"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %% [markdown]
# bmi Vs expenses

# %%
sns.scatterplot(df.bmi,df.expenses)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
sns.regplot(df["bmi"], df["expenses"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %% [markdown]
# # Comparing the Three Columns

# %% [markdown]
# age Vs bmi on sex

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["sex"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %% [markdown]
# age Vs expenses on sex

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["sex"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %% [markdown]
# bmi Vs expenses on sex

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["sex"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %% [markdown]
# age Vs bmi on children

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["children"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %% [markdown]
# age Vs expenses on children

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["children"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %% [markdown]
# bmi Vs expenses on children

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["children"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %% [markdown]
# age Vs bmi on smoker

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["smoker"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %% [markdown]
# age Vs expenses on smoker

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["smoker"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %% [markdown]
# bmi Vs expenses on smoker

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["smoker"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
age Vs bmi on region

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["region"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
age Vs expenses on region

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["region"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
bmi Vs expenses on region

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["region"])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %% [markdown]
# # Here we will Check for Four Columns

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["sex"], style=df['smoker'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["sex"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["sex"], style=df['children'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["children"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["children"], style=df['smoker'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["children"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["children"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["children"], style=df['smoker'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["children"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["children"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["children"], style=df['children'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["smoker"], style=df['smoker'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(df["age"], df["bmi"], hue=df["region"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["sex"], style=df['sex'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["children"], style=df['children'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["smoker"], style=df['smoker'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.scatterplot(df["age"], df["expenses"], hue=df["region"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["sex"], style=df['sex'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["children"], style=df['children'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["smoker"], style=df['smoker'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(df["bmi"], df["expenses"], hue=df["region"], style=df['region'])
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %% [markdown]
#  Box Plot

# %%
sns.boxplot(data=df,orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature Engineering

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#       age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0      19  27.9         0  16884.92         0           1                 0
# 1      18  33.8         1   1725.55         1           0                 0
# 2      28  33.0         3   4449.46         1           0                 0
# 3      33  22.7         0  21984.47         1           0                 1
# 4      32  28.9         0   3866.86         1           0                 1
# ...   ...   ...       ...       ...       ...         ...               ...
# 1333   50  31.0         3  10600.55         1           0                 1
# 1334   18  31.9         0   2205.98         0           0                 0
# 1335   18  36.9         0   1629.83         0           0                 0
# 1336   21  25.8         0   2007.95         0           0                 0
# 1337   61  29.1         0  29141.36         0           1                 1
#
#       region_southeast  region_southwest
# ...

# %%
df.corr()
# Out:
#                        age       bmi  children  expenses  sex_male  \
# age               1.000000  0.109341  0.042469  0.299008 -0.020856
# bmi               0.109341  1.000000  0.012645  0.198576  0.046380
# children          0.042469  0.012645  1.000000  0.067998  0.017163
# expenses          0.299008  0.198576  0.067998  1.000000  0.057292
# sex_male         -0.020856  0.046380  0.017163  0.057292  1.000000
# smoker_yes       -0.025019  0.003968  0.007673  0.787251  0.076185
# region_northwest -0.000407 -0.135992  0.024806 -0.039905 -0.011156
# region_southeast -0.011642  0.270144 -0.023066  0.073982  0.017117
# region_southwest  0.010016 -0.006398  0.021914 -0.043210 -0.004184
#
#                   smoker_yes  region_northwest  region_southeast  \
# age                -0.025019         -0.000407         -0.011642
# bmi                 0.003968         -0.135992          0.270144
# children            0.007673          0.024806         -0.023066
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.pairplot(df)

# %%
#correlations of each features in Data
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(12,9))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df.head()
# Out:
#    age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0  16884.92         0           1                 0
# 1   18  33.8         1   1725.55         1           0                 0
# 2   28  33.0         3   4449.46         1           0                 0
# 3   33  22.7         0  21984.47         1           0                 1
# 4   32  28.9         0   3866.86         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
df.head()
# Out:
#    age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0  16884.92         0           1                 0
# 1   18  33.8         1   1725.55         1           0                 0
# 2   28  33.0         3   4449.46         1           0                 0
# 3   33  22.7         0  21984.47         1           0                 1
# 4   32  28.9         0   3866.86         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
X=df.drop(columns=['expenses'])

# %%
y=df['expenses']

# %%
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %%
X
# Out:
#       age   bmi  children  sex_male  smoker_yes  region_northwest  \
# 0      19  27.9         0         0           1                 0
# 1      18  33.8         1         1           0                 0
# 2      28  33.0         3         1           0                 0
# 3      33  22.7         0         1           0                 1
# 4      32  28.9         0         1           0                 1
# ...   ...   ...       ...       ...         ...               ...
# 1333   50  31.0         3         1           0                 1
# 1334   18  31.9         0         0           0                 0
# 1335   18  36.9         0         0           0                 0
# 1336   21  25.8         0         0           0                 0
# 1337   61  29.1         0         0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.6,random_state=23)

# %% [markdown]
# # Random Forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
random_forest_reg = RandomForestRegressor(n_estimators=400, max_depth=5, random_state=13)
random_forest_reg.fit(X_train, y_train)
#MSE
y_pred5 = random_forest_reg.predict(X_test)
#Evaluvation: MSE
from sklearn.metrics import mean_squared_error
RM = mean_squared_error(y_pred5, y_test)
#R_square
Random_forest=random_forest_reg.score(X_test,y_test)

# %%
Random_forset
# Out:
# 0.8493374530491034

# %%
print("MSE : ",mean_squared_error(y_pred5,y_test))
print("MAE : ",mean_absolute_error(y_pred5,y_test))
print("R Score :",r2_score(y_pred5,y_test))
# Out:
# MSE :  21729568.033768326
# MAE :  2629.415133563616
# R Score : 0.8373254581281352

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred5))
print('MSE:', metrics.mean_squared_error(y_test, y_pred5))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred5)))
# Out:
# MAE: 2629.415133563616
# MSE: 21729568.033768326
# RMSE: 4661.498475143838

# %% [markdown]
# # Linear Regression

# %%
# Scikit Learn module
from sklearn.linear_model import LinearRegression


lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)

y_pred_LR = lin_reg.predict(X_test)

#Evaluvation: MSE
from sklearn.metrics import mean_squared_error
J_mse_sk_LR = mean_squared_error(y_pred_LR, y_test)

# R_square
R_square_sk_LR = lin_reg.score(X_test,y_test)

print('The Mean Square Error(MSE) or J(theta) is: ',J_mse_sk_LR)
print('R square obtain for scikit learn library is :',R_square_sk_LR)
# Out:
# The Mean Square Error(MSE) or J(theta) is:  35690803.578237854
# R square obtain for scikit learn library is : 0.7525368492615649

# %% [markdown]
# # Lasso Linear Regression¶

# %%
# Scikit Learn module
from sklearn.linear_model import Lasso


lin_reg_lasso = Lasso()
lin_reg_lasso.fit(X_train,y_train)

y_pred_LR_lasso = lin_reg_lasso.predict(X_test)

#Evaluvation: MSE
from sklearn.metrics import mean_squared_error
J_mse_sk_lasso = mean_squared_error(y_pred_LR_lasso, y_test)

# R_square
R_square_sk_lasso = lin_reg_lasso.score(X_test,y_test)

print('The Mean Square Error(MSE) or J(theta) is: ',J_mse_sk_lasso)
print('R square obtain for scikit learn library is :',R_square_sk_lasso)
# Out:
# The Mean Square Error(MSE) or J(theta) is:  35681009.32755083
# R square obtain for scikit learn library is : 0.7526047579632791

# %%
J_mse_sk_lasso
# Out:
# 35681009.32755083

# %% [markdown]
# # Ridge Linear Regression

# %%
# Scikit Learn module
from sklearn.linear_model import Ridge


lin_reg_ridge = Ridge()
lin_reg_ridge.fit(X_train,y_train)

y_pred_LR_ridge = lin_reg_ridge.predict(X_test)

#Evaluvation: MSE
from sklearn.metrics import mean_squared_error
J_mse_sk_LR_ridge = mean_squared_error(y_pred_LR_ridge, y_test)

# R_square
R_square_sk_LR_ridge = lin_reg_ridge.score(X_test,y_test)

print('The Mean Square Error(MSE) or J(theta) is: ',J_mse_sk_LR_ridge)
print('R square obtain for scikit learn library is :',R_square_sk_LR_ridge)
# Out:
# The Mean Square Error(MSE) or J(theta) is:  35673420.526166335
# R square obtain for scikit learn library is : 0.7526573751226776

# %% [markdown]
# # Support Vector Machine

# %%
# Support Vector Machine's 
from sklearn.svm import SVR

SVM_R = SVR(kernel='rbf')
SVM_R.fit(X_train, y_train)

y_pred_svm = SVM_R.predict(X_test)

#Evaluvation: MSE
from sklearn.metrics import mean_squared_error
J_mse_sk_svm = mean_squared_error(y_pred_svm, y_test)

# R_square
R_square_sk_svm = SVM_R.score(X_test,y_test)

print('The Mean Square Error(MSE) or J(theta) is: ',J_mse_sk_svm)
print('R square obtain for scikit learn library is :',R_square_sk_svm)
# Out:
# The Mean Square Error(MSE) or J(theta) is:  155501450.0404656
# R square obtain for scikit learn library is : -0.07817350447307736

# %%
MSE = [J_mse_sk_LR,J_mse_sk_LR_ridge,J_mse_sk_lasso,J_mse_sk_svm,RM]
R_square = [R_square_sk_LR, R_square_sk_LR_ridge,R_square_sk_lasso,R_square_sk_svm,Random_forset]
models = ['Linear Regression', 'Linear Regression (Ridge)' , 'Linear Regression (Lasso)', 'Support Vector Machine','Random forest']

# %%
sns.barplot(MSE, models, color="g")
#plt.xlim([70,100])
plt.xlabel('Mean Square Error')
plt.title('Mean Square Error')
plt.show()
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(R_square, models, color="b")
plt.xlim([-0.1,1.0])
plt.xlabel('R-Square')
plt.title('R-Square')
plt.show()
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It is found that the MSE with the Random Forest (SVM) model is lowest of all the tried models
# and the R-Square value is highest among all.
#
# Thus Random Forest  seems to be the best for this data.

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.12970875 0.19062437 0.02430871 0.0106422  0.62059197 0.00931275
#  0.00875376 0.0060575 ]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# # Random Forest Regression with Hyper parameter Technique

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()

# %%
regressor
# Out:
# RandomForestRegressor()

# %%
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = regressor.predict(X_test)
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)

# %%
score
# Out:
# 0.8370097901190942

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,
                     scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.3s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 5,
#  'min_samples_leaf': 5,
#  'max_features': 'auto',
#  'max_depth': 15}

# %%
rf_random.best_score_
# Out:
# -21602070.53197292

# %%
regressor=RandomForestRegressor(
    n_estimators=400,

    criterion='mse',
    max_depth=15,
    min_samples_split=5,
    min_samples_leaf=5,
    min_weight_fraction_leaf=0.0,
    max_features='auto',
    max_leaf_nodes=None,
    min_impurity_decrease=0.0,
    bootstrap=True,
    oob_score=False,
    n_jobs=None,
    random_state=None,
    verbose=0,
    warm_start=False,
    ccp_alpha=0.0,
    max_samples=None,
)

# %%
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=5,
#                       n_estimators=400)

# %%
y_pred = regressor.predict(X_test)
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)

# %%
score
# Out:
# 0.8528176449214949

# %%
predictions=rf_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='expenses', ylabel='Density'>

# %%
predictions=rf_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# C:\Users\Sasi kumar G\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='expenses', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# # Model Deployment

# %%
import pickle
# open a file, where you ant to store the data
file=open('insurance_prediction_model.pkl','wb')

# dump information to that file
pickle.dump(rf_random,file)
